# %% [markdown]
# # Растровые изображения
#
# ![](./images/sample_grid_a_square.png)

# %% [markdown]
# # Растеризация векторного изображения
#
# ![](images/sample_grid_a_circle.png)

# %% [markdown]
# # Глубина цвета

# %% [markdown]
# ![](images/quantification.png)

# %% [markdown]
# # Цветное изображение

# %% [markdown]
# ![a](images/reign_pic_breakdown.png)

# %% [markdown]
# ![a](images/three_d_array.png)

# %%
import numpy as np

import cv2

img = plt.imread("example.png")
type(img), img.shape, img.dtype, img.min(), img.max()
# Out:
# (numpy.ndarray, (800, 800, 4), dtype('float32'), 0.0, 1.0)

# %%
import matplotlib.pyplot as plt 

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 799.5, 799.5, -0.5)

# %%
plt.imshow(img[..., 2], cmap="Blues", vmax=1.0)
plt.axis("off")
# Out:
# (-0.5, 799.5, 799.5, -0.5)

# %%
fragment = img[300:450, 100:200, :]
plt.imshow(fragment)
plt.axis("off")
# Out:
# (-0.5, 99.5, 149.5, -0.5)

# %%
noise = np.random.random((200, 200))
plt.imshow(noise, cmap="gray")
plt.axis(False)
# Out:
# (-0.5, 199.5, 199.5, -0.5)

# %%
plt.imsave("noise.png", noise, cmap="gray")
